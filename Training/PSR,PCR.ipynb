# %%
#!pip install finterstellar
# Out:
# Requirement already satisfied: finterstellar in c:\users\esthe\anaconda3\lib\site-packages (0.1.19)
# Requirement already satisfied: pandas-datareader>=0.10.0 in c:\users\esthe\anaconda3\lib\site-packages (from finterstellar) (0.10.0)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\esthe\anaconda3\lib\site-packages (from finterstellar) (1.21.5)
# Requirement already satisfied: lxml>=4.2.6 in c:\users\esthe\anaconda3\lib\site-packages (from finterstellar) (4.8.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\esthe\anaconda3\lib\site-packages (from finterstellar) (1.4.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\esthe\anaconda3\lib\site-packages (from finterstellar) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\esthe\anaconda3\lib\site-packages (from pandas>=1.1.4->finterstellar) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\esthe\anaconda3\lib\site-packages (from pandas>=1.1.4->finterstellar) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\esthe\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1.4->finterstellar) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\esthe\anaconda3\lib\site-packages (from requests>=2.23.0->finterstellar) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\esthe\anaconda3\lib\site-packages (from requests>=2.23.0->finterstellar) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\esthe\anaconda3\lib\site-packages (from requests>=2.23.0->finterstellar) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\esthe\anaconda3\lib\site-packages (from requests>=2.23.0->finterstellar) (2021.10.8)

# %%
import finterstellar as fs
OTP = "16692264001011151161"

# %% [markdown]
# # PSR

# %%
df = fs.fn_single(otp=OTP, symbol='WMT', window='T')

# %%
df['SPS'] = df['Revenue'] / df['Shares'] 
df['PSR'] = df['Price'] / df['SPS'] 
fs.draw_chart(df, left='PSR', right='Price')

# %%
fs.draw_price_multiple_band(df, multiple='PSR', acct='SPS')

# %%
terms = fs.set_terms(trade_start='2020Q1', trade_end='2021Q1') 
data = {}

for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['SPS'] = data[t]['Revenue'] / data[t]['Shares'] 
    data[t]['PSR'] = data[t]['Price_M3'] / data[t]['SPS'] 
    s[t] = fs.fn_filter(data[t], by='PSR', floor=.1, cap=10, n=30, asc=True) 
    signal[t] = list(s[t].index) 

df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 364.38%
# Accumulated return: 364.38%
# Investment period: 1.0yrs
# Sharpe ratio: 6.25
# MDD: 0.00%

# %%
fs.draw_return(df)

# %%
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}

for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['SPS'] = data[t]['Revenue'] / data[t]['Shares'] 
    data[t]['PSR'] = data[t]['Price_M3'] / data[t]['SPS'] 
    s[t] = fs.fn_filter(data[t], by='PSR', floor=.1, cap=10, n=30, asc=True) 
    signal[t] = list(s[t].index) 

df1 = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 33.28%
# Accumulated return: 1673.13%
# Investment period: 10.0yrs
# Sharpe ratio: 4.41
# MDD: -30.92%

# %%
fs.draw_return(df1)

# %% [markdown]
# # PCR

# %%
df = fs.fn_single(otp=OTP, symbol='MCD', window='T')

# %%
df['OCF'] = df['Net Income'] + df['Depreciation']
df['CFPS'] = df['OCF'] / df['Shares'] 
df['PCR'] = df['Price'] / df['CFPS'] 
fs.draw_chart(df, left='PCR', right='Price')

# %%
fs.draw_price_multiple_band(df, multiple='PCR', acct='CFPS')

# %%
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1') 
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['CFPS'] = (data[t]['Net Income'] + data[t]['Depreciation']) / data[t]['Shares'] 
    data[t]['PCR'] = data[t]['Price_M3'] / data[t]['CFPS'] 
    s[t] = fs.fn_filter(data[t], by='PCR', floor=.1, cap=10, n=30, asc=True)
    signal[t] = list(s[t].index) 
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 17.11%
# Accumulated return: 385.89%
# Investment period: 10.0yrs
# Sharpe ratio: 0.90
# MDD: -49.48%

# %%
fs.draw_return(df)

# %%
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['CFPS'] = (data[t]['Net Income'] + data[t]['Depreciation']) / data[t]['Shares'] 
    data[t]['PCR'] = data[t]['Price_M3'] / data[t]['CFPS'] 
    s[t] = fs.fn_filter(data[t], by='PCR', floor=.1, cap=10, n=10, asc=True) 
    signal[t] = list(s[t].index) 

df3 = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 25.92%
# Accumulated return: 904.13%
# Investment period: 10.0yrs
# Sharpe ratio: 1.74
# MDD: -39.47%

# %%
fs.draw_return(df3)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 2011Q1 to 2021Q1
# Columns: 150 entries, GTX to term_exs_rtn
# dtypes: float64(150)
# memory usage: 48.4+ KB

# %% [markdown]
# # PSR(앞선 5년)

# %%
terms = fs.set_terms(trade_start='2006Q1', trade_end='2011Q1')
data = {}

for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['SPS'] = data[t]['Revenue'] / data[t]['Shares'] 
    data[t]['PSR'] = data[t]['Price_M3'] / data[t]['SPS'] 
    s[t] = fs.fn_filter(data[t], by='PSR', floor=.1, cap=10, n=30, asc=True) 
    signal[t] = list(s[t].index) 

df2 = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2005Q4...OK
# 2006Q1...OK
# 2006Q2...OK
# 2006Q3...OK
# 2006Q4...OK
# 2007Q1...OK
# 2007Q2...OK
# 2007Q3...OK
# 2007Q4...OK
# 2008Q1...OK
# 2008Q2...OK
# 2008Q3...OK
# 2008Q4...OK
# 2009Q1...OK
# 2009Q2...OK
# 2009Q3...OK
# 2009Q4...OK
# 2010Q1...OK
# 2010Q2...OK
# 2010Q3...OK
# 2010Q4...OK
# CAGR: 12.58%
# Accumulated return: 80.91%
# Investment period: 5.0yrs
# Sharpe ratio: 0.57
# MDD: -46.63%

# %% [markdown]
# # PCR(앞선 5년)

# %%
terms = fs.set_terms(trade_start='2008Q1', trade_end='2011Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['CFPS'] = (data[t]['Net Income'] + data[t]['Depreciation']) / data[t]['Shares'] 
    data[t]['PCR'] = data[t]['Price_M3'] / data[t]['CFPS'] 
    s[t] = fs.fn_filter(data[t], by='PCR', floor=.1, cap=10, n=10, asc=True) 
    signal[t] = list(s[t].index) 

df4 = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2007Q4...OK
# 2008Q1...OK
# 2008Q2...OK
# 2008Q3...OK
# 2008Q4...OK
# 2009Q1...OK
# 2009Q2...OK
# 2009Q3...OK
# 2009Q4...OK
# 2010Q1...OK
# 2010Q2...OK
# 2010Q3...OK
# 2010Q4...OK
# CAGR: 27.64%
# Accumulated return: 107.95%
# Investment period: 3.0yrs
# Sharpe ratio: 1.02
# MDD: -32.43%

# %%
fs.draw_return(df4)

# %% [markdown]
# # PSR(20년)

# %%
terms = fs.set_terms(trade_start='2006Q1', trade_end='2021Q1')
data = {}

for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['SPS'] = data[t]['Revenue'] / data[t]['Shares'] 
    data[t]['PSR'] = data[t]['Price_M3'] / data[t]['SPS'] 
    s[t] = fs.fn_filter(data[t], by='PSR', floor=.1, cap=10, n=30, asc=True) 
    signal[t] = list(s[t].index) 

PSR_df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2005Q4...OK
# 2006Q1...OK
# 2006Q2...OK
# 2006Q3...OK
# 2006Q4...OK
# 2007Q1...OK
# 2007Q2...OK
# 2007Q3...OK
# 2007Q4...OK
# 2008Q1...OK
# 2008Q2...OK
# 2008Q3...OK
# 2008Q4...OK
# 2009Q1...OK
# 2009Q2...OK
# 2009Q3...OK
# 2009Q4...OK
# 2010Q1...OK
# 2010Q2...OK
# 2010Q3...OK
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 25.99%
# Accumulated return: 3107.75%
# Investment period: 15.0yrs
# Sharpe ratio: 5.89
# MDD: -46.63%

# %% [markdown]
# # PBR(20년)

# %%
terms = fs.set_terms(trade_start='2006Q1', trade_end='2021Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp=OTP, term=t) 

s = {}
signal = {}
for t in terms:
    data[t]['CFPS'] = (data[t]['Net Income'] + data[t]['Depreciation']) / data[t]['Shares'] 
data[t]['PCR'] = data[t]['Price_M3'] / data[t]['CFPS'] 
    s[t] = fs.fn_filter(data[t], by='PCR', floor=.1, cap=10, n=10, asc=True) 
    signal[t] = list(s[t].index) 

PCR_df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# 2005Q4...OK
# 2006Q1...OK
# 2006Q2...OK
# 2006Q3...OK
# 2006Q4...OK
# 2007Q1...OK
# 2007Q2...OK
# 2007Q3...OK
# 2007Q4...OK
# 2008Q1...OK
# 2008Q2...OK
# 2008Q3...OK
# 2008Q4...OK
# 2009Q1...OK
# 2009Q2...OK
# 2009Q3...OK
# 2009Q4...OK
# 2010Q1...OK
# 2010Q2...OK
# 2010Q3...OK
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 24.66%
# Accumulated return: 2634.20%
# Investment period: 15.0yrs
# Sharpe ratio: 3.85
# MDD: -39.47%
