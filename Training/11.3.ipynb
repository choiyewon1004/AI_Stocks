# %% [markdown]
# # 6. PAA
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. VAA
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 8. VAA 중도형
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 9. DAA - 수비
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 11. LAA - 영구 포트폴리오부터
# ![image.png](attachment:image.png)
#
# https://nbviewer.org/github/FinanceData/FinanceDataReader/blob/master/tutorial/FinanceDataReader%20Tutorial%20-%20FRED%20%EA%B2%BD%EA%B8%B0%20%EC%84%A0%ED%96%89%20%EC%A7%80%ED%91%9C.ipynb?fbclid=IwAR1B3dPzdjhrgsP-0XJ1cEch6ULjqM4T2_t5jI5ffXVMbE2IVOJOl8XH8ow

# %% [markdown]
# # 12. MDD 최소화 전략 - 각자 읽기

# %% [markdown]
# # 15. 한국형 할로윈
#
# ![image.png](attachment:image.png)
#
# - 11 주식을 살때 , 내년 4월에 팔기
# - 5 채권을 살때 , 10월에 팔기
# - 종목을 살때는 10월 말정도에 사고 내년 4월 정도에 팔고 5~10까지는 주식 안가지 있는다
# - 예외가 생기면 ? --> 어느정도 손실나면 손절

# %% [markdown]
# # 16. 전략 합성 - 응용 관점
#
# ![image.png](attachment:image.png)
